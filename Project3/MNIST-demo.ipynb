# %%
from Projects.Project3.configurator import get_and_split_dataset, run_SSN_training_regime, run_SCN_training_regime, compare_SSN_and_SCN

# %%
# Global parameters for both SSN and SCN
dataset_name = 'MNIST' # AVAILABLE  #'CIFAR10' # 'KMNIST' #'FashionMNIST' #
D1_fraction = 0.8
D2_train_val_test_fraction = (0.1, 0.1)

latent_vector_size = 64
batch_size = 16

# Parameters for Autoencoder training
autoencoder_learning_rate = 0.2
autoencoder_loss_function = 'binary_cross_entropy' #AVAILABLE 'binary_cross_entropy'
autoencoder_optimizer = 'SGD' #AVAILABLE 'SGD' # 'adam' #
autoencoder_epochs = 3

freeze_encoder_weights = True
plot_t_sne = True
n_reconstructions_to_display = 10

# Parameters for classifier training
classifier_learning_rate = 0.0002
classifier_loss_function = 'cross_entropy' #AVAILABLE 'cross_entropy'
classifier_optimizer = 'SGD' #AVAILABLE 'SGD' # 'adam' #
classifier_epochs = 10

# %%
dataloaders, \
image_dimensions,\
num_classes \
        = get_and_split_dataset(dataset_name, D1_fraction, D2_train_val_test_fraction, batch_size)

# %%
SSN_trainer = run_SSN_training_regime(
        dataloaders,
        autoencoder_learning_rate,
        autoencoder_loss_function,
        autoencoder_optimizer,
        autoencoder_epochs,

        classifier_learning_rate,
        classifier_loss_function,
        classifier_optimizer,
        classifier_epochs,

        latent_vector_size,
        batch_size,
        num_classes,
        image_dimensions,

        freeze_encoder_weights,
        n_reconstructions_to_display,
        plot_t_sne
    )
# Out:
# Autoencoder(
#   (encoder): Encoder(
#     (model): Sequential(
#       (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(3, 3), padding=(1, 1))
#       (1): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (2): ReLU()
#       (3): Flatten(start_dim=1, end_dim=-1)
#       (4): Linear(in_features=3200, out_features=64, bias=True)
#     )
#   )
#   (decoder): Decoder(
#     (model): Sequential(
#       (0): Linear(in_features=64, out_features=3200, bias=True)
#       (1): Unflatten(dim=1, unflattened_size=(32, 10, 10))
#       (2): ConvTranspose2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (3): ConvTranspose2d(16, 1, kernel_size=(3, 3), stride=(3, 3), padding=(1, 1))
#       (4): ReLU()
#       (5): Sigmoid()
#     )
#   )
# )
# Epoch: 0, Iteration: 600, Validation loss: 0.6931, Validation accuracy N/A
# Epoch: 0, Iteration: 1200, Validation loss: 0.6929, Validation accuracy N/A
# Epoch: 0, Iteration: 1800, Validation loss: 0.6923, Validation accuracy N/A
# Epoch: 0, Iteration: 2400, Validation loss: 0.6895, Validation accuracy N/A
# Epoch: 0, Iteration: 3000, Validation loss: 0.5211, Validation accuracy N/A
# Epoch: 1, Iteration: 3600, Validation loss: -4.3938, Validation accuracy N/A
# Epoch: 1, Iteration: 4200, Validation loss: -5.6268, Validation accuracy N/A
# Epoch: 1, Iteration: 4800, Validation loss: -6.0738, Validation accuracy N/A
# Epoch: 1, Iteration: 5400, Validation loss: -6.213, Validation accuracy N/A
# Epoch: 1, Iteration: 6000, Validation loss: -6.4265, Validation accuracy N/A
# Epoch: 2, Iteration: 6600, Validation loss: -6.59, Validation accuracy N/A
# Epoch: 2, Iteration: 7200, Validation loss: -6.685, Validation accuracy N/A
# Epoch: 2, Iteration: 7800, Validation loss: -6.6944, Validation accuracy N/A
# Epoch: 2, Iteration: 8400, Validation loss: -6.7665, Validation accuracy N/A
# Epoch: 2, Iteration: 9000, Validation loss: -6.7737, Validation accuracy N/A
# Classifier(
#   (encoder): Encoder(
#     (model): Sequential(
#       (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(3, 3), padding=(1, 1))
#       (1): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (2): ReLU()
#       (3): Flatten(start_dim=1, end_dim=-1)
#       (4): Linear(in_features=3200, out_features=64, bias=True)
#     )
#   )
#   (classifier_head): ClassifierHead(
#     (model): Sequential(
#       (0): Linear(in_features=64, out_features=10, bias=True)
#     )
#   )
# )
# Epoch: 0, Iteration: 600, Validation loss: 1.8386, Validation accuracy 0.685
# Epoch: 1, Iteration: 1200, Validation loss: 1.1267, Validation accuracy 0.7592
# Epoch: 2, Iteration: 1800, Validation loss: 0.8668, Validation accuracy 0.7975

# %%
 SCN_trainer = run_SCN_training_regime(
        dataloaders,
        classifier_learning_rate,
        classifier_loss_function,
        classifier_optimizer,
        latent_vector_size,
        classifier_epochs,
        batch_size,
        image_dimensions,
        num_classes
    )

# %%
 SCN_trainer = run_SCN_training_regime(
        dataloaders,
        classifier_learning_rate,
        classifier_loss_function,
        classifier_optimizer,
        latent_vector_size,
        classifier_epochs,
        batch_size,
        image_dimensions,
        num_classes
    )
